# %%
# import sys
# sys.path.append("../../semi-supervised")
# from functools import reduce
# from operator import __or__
# from torch.utils.data.sampler import SubsetRandomSampler
# from torchvision.datasets import MNIST
# import torchvision.transforms as transforms
# from utils import onehot
# 
# location = "./"
# n_labels = 10
# 
# mnist_train = MNIST(location, train=True, download=True)
# numpy_mnist = mnist_train.data.numpy().reshape(-1, 784) / 255
# mnist_mean = numpy_mnist.mean(0)
# mnist_std = numpy_mnist.std(0)
# 
# mnist_indices = np.where(mnist_std > 0.1)
# 
# 
# 
# flatten_bernoulli = lambda x: transforms.ToTensor()(x).view(-1)[mnist_indices].bernoulli()
# 
# mnist_train = MNIST(location, train=True, download=True,
#                     transform=flatten_bernoulli, target_transform=onehot(n_labels))
# mnist_valid = MNIST(location, train=False, download=True,
#                     transform=flatten_bernoulli, target_transform=onehot(n_labels))
#

# %%
# Imports
import torch
cuda = torch.cuda.is_available()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append("../../semi-supervised")

torch.multiprocessing.set_sharing_strategy('file_system')

# %% [markdown]
# # Auxiliary Deep Generative Model
#
# The Auxiliary Deep Generative Model [[Maaløe, 2016]](https://arxiv.org/abs/1602.05473) posits a model that with an auxiliary latent variable $a$ that infers the variables $z$ and $y$. This helps in terms of semi-supervised learning by delegating causality to their respective variables. This model was state-of-the-art in semi-supervised until 2017, and is still very powerful with an MNIST accuracy of *99.4%* using just 10 labelled examples per class.
#
# <img src="../images/adgm.png" width="400px"/>

# %%
from models import AuxiliaryDeepGenerativeModel

y_dim = 10
# z_dim = 300
# a_dim = 300
x_dim = 784
z_dim = 100
a_dim = 100
h_dim = [500, 500]
# h_dim = [1000, 1000]

# TODO: trzeba zrobić redukcje wymiarowości przez std < 0.1
# model = AuxiliaryDeepGenerativeModel([3072, y_dim, z_dim, a_dim, h_dim])
model = AuxiliaryDeepGenerativeModel([x_dim, y_dim, z_dim, a_dim, h_dim], batch_norm=False)
model
# Out:
# 784
# Linear layers in classifier [ReLU(), BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), Linear(in_features=500, out_features=500, bias=True), ReLU(), BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)]
# [784, 100]
# Linear layers in classifier [ReLU(), Linear(in_features=500, out_features=500, bias=True), ReLU()]
# ../../semi-supervised/models/vae.py:235: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   init.xavier_normal(m.weight.data)
# ../../semi-supervised/models/dgm.py:109: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   init.xavier_normal(m.weight.data)
# AuxiliaryDeepGenerativeModel(
#   (encoder): Encoder(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=784, out_features=500, bias=True)
#       (1): Linear(in_features=10, out_features=500, bias=True)
#       (2): Linear(in_features=100, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): ReLU()
#       (1): Linear(in_features=500, out_features=500, bias=True)
#       (2): ReLU()
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=500, out_features=100, bias=True)
#       (log_var): Linear(in_features=500, out_features=100, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=100, out_features=500, bias=True)
#       (1): Linear(in_features=10, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): ReLU()
#       (1): Linear(in_features=500, out_features=500, bias=True)
#       (2): ReLU()
#     )
#     (reconstruction): Linear(in_features=500, out_features=784, bias=True)
#   )
#   (classifier): Classifier(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=784, out_features=500, bias=True)
#       (1): Linear(in_features=100, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): ReLU()
#       (1): Linear(in_features=500, out_features=500, bias=True)
#       (2): ReLU()
#     )
#     (logits): Linear(in_features=500, out_features=10, bias=True)
#   )
#   (aux_encoder): Encoder(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=784, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): ReLU()
#       (1): Linear(in_features=500, out_features=500, bias=True)
#       (2): ReLU()
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=500, out_features=100, bias=True)
#       (log_var): Linear(in_features=500, out_features=100, bias=True)
#     )
#   )
#   (aux_decoder): Encoder(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=784, out_features=500, bias=True)
#       (1): Linear(in_features=10, out_features=500, bias=True)
#       (2): Linear(in_features=100, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): ReLU()
#       (1): Linear(in_features=500, out_features=500, bias=True)
#       (2): ReLU()
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=500, out_features=100, bias=True)
#       (log_var): Linear(in_features=500, out_features=100, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Training
#
# The lower bound we derived in the notebook for the **deep generative model** is similar to the one for the ADGM. Here, we also need to integrate over a continuous auxiliary variable $a$.
#
# For labelled data, the lower bound is given by.
# \begin{align}
# \log p(x,y) &= \log \int \int p(x, y, a, z) \ dz \ da\\
# &\geq \mathbb{E}_{q(a,z|x,y)} \bigg [\log \frac{p(x,y,a,z)}{q(a,z|x,y)} \bigg ] = - \mathcal{L}(x,y)
# \end{align}
#
# Again when no label information is available we sum out all of the labels.
#
# \begin{align}
# \log p(x) &= \log \int \sum_{y} \int p(x, y, a, z) \ dz \ da\\
# &\geq \mathbb{E}_{q(a,y,z|x)} \bigg [\log \frac{p(x,y,a,z)}{q(a,y,z |x)} \bigg ] = - \mathcal{U}(x)
# \end{align}
#
# Where we decompose the q-distribution into its constituent parts. $q(a, y, z|x) = q(z|a,y,x)q(y|a,x)q(a|x)$, which is also what can be seen in the figure.
#
# The distribution over $a$ is similar to $z$ in the sense that it is also a diagonal Gaussian distribution. However by introducing the auxiliary variable we allow for $z$ to become arbitrarily complex - something we can also see when using normalizing flows.

# %%
from datautils import get_mnist, get_svhn

# Only use 10 labelled examples per class
# The rest of the data is unlabelled.
labelled, unlabelled, validation, mnist_mean, mnist_std = get_mnist(location="./", batch_size=100, labels_per_class=10, preprocess=False)
# labelled, unlabelled, validation = get_svhn(location="./", batch_size=1000, labels_per_class=100)

alpha = .1 * (len(unlabelled) + len(labelled)) / len(labelled)

def binary_cross_entropy(r, x):
    return -torch.sum(x * torch.log(r + 1e-8) + (1 - x) * torch.log(1 - r + 1e-8), dim=-1)

def mse(r, x):
    return torch.sum(torch.pow(x - r, 2), dim=-1)


optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999), weight_decay=0.5 / 60000)

# %%
from itertools import cycle
from inference import SVI, DeterministicWarmup, ImportanceWeightedSampler

# We will need to use warm-up in order to achieve good performance.
# Over 200 calls to SVI we change the autoencoder from
# deterministic to stochastic.
# beta = DeterministicWarmup(n=0)
iw_sampler = ImportanceWeightedSampler(mc=10, iw=1)


if cuda: model = model.cuda()
elbo = SVI(model, likelihood=binary_cross_entropy, sampler=iw_sampler)

# %% [markdown]
# The library is conventially packed with the `SVI` method that does all of the work of calculating the lower bound for both labelled and unlabelled data depending on whether the label is given. It also manages to perform the enumeration of all the labels.
#
# Remember that the labels have to be in a *one-hot encoded* format in order to work with SVI.

# %%
from torch.autograd import Variable
from torch.nn.utils.clip_grad import clip_grad_value_, clip_grad_norm_

from tqdm import tnrange


for epoch in tnrange(200):
    model.train()
    total_loss, accuracy = (0, 0)
    for (x, y), (u, _) in zip(cycle(labelled), unlabelled):
        # Wrap in variables
        x, y, u = Variable(x), Variable(y), Variable(u)

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            u = u.cuda(device=0)

        L = -elbo(x, y)
        U = -elbo(u)

        # Add auxiliary classification loss q(y|x)
        # Resample (Monte Carlo)
        x = x.repeat(10, 1)
        logits = model.classify(x)
        
        # Regular cross entropy
        classication_loss = torch.sum(y.repeat(10, 1) * torch.log(logits + 1e-8), dim=1).mean()

        J_alpha = L - alpha * classication_loss + U

        J_alpha.backward()
        clip_grad_norm_(model.parameters(), 5.)
        clip_grad_value_(model.parameters(), 1.)
        
        
        optimizer.step()
        optimizer.zero_grad()

        logits = logits.reshape(10, -1, logits.shape[-1]).mean(0)
        total_loss += J_alpha.item()
        accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
        
    if epoch % 1 == 0:
        model.eval()
        m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        print("[Train]\t\t J_a: {:.4f}, accuracy: {:.4f}".format(total_loss / m, accuracy / m))

        total_loss, accuracy = (0, 0)
        for x, y in validation:
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            L = -elbo(x, y)
            U = -elbo(x)

            # More samples for better estimation
            x = x.repeat(100, 1)
            logits = model.classify(x)
            logits = logits.reshape(100, -1, logits.shape[-1]).mean(0)
            
            classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

            J_alpha = L + alpha * classication_loss + U

            total_loss += J_alpha.item()

            _, pred_idx = torch.max(logits, 1)
            _, lab_idx = torch.max(y, 1)
            accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

        m = len(validation)
        print("[Validation]\t J_a: {:.4f}, accuracy: {:.4f}".format(total_loss / m, accuracy / m))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Epoch: 0
# [Train]		 J_a: 151.7027, accuracy: 1.0000
# [Validation]	 J_a: 222.6957, accuracy: 0.9590
# Epoch: 1
# [Train]		 J_a: 151.7133, accuracy: 1.0000
# [Validation]	 J_a: 223.7742, accuracy: 0.9569
# Epoch: 2
# [Train]		 J_a: 151.6758, accuracy: 1.0000
# [Validation]	 J_a: 222.8517, accuracy: 0.9570
# Epoch: 3
# [Train]		 J_a: 151.6319, accuracy: 1.0000
# [Validation]	 J_a: 223.0100, accuracy: 0.9570
# Epoch: 4
# [Train]		 J_a: 151.6358, accuracy: 1.0000
# [Validation]	 J_a: 222.0492, accuracy: 0.9595
# Epoch: 5
# [Train]		 J_a: 151.5883, accuracy: 1.0000
# [Validation]	 J_a: 221.9404, accuracy: 0.9582
# Epoch: 6
# [Train]		 J_a: 151.5652, accuracy: 1.0000
# [Validation]	 J_a: 222.9305, accuracy: 0.9581
# Epoch: 7
# [Train]		 J_a: 151.5447, accuracy: 1.0000
# [Validation]	 J_a: 223.4360, accuracy: 0.9584
# Epoch: 8
# [Train]		 J_a: 151.5105, accuracy: 1.0000
# [Validation]	 J_a: 222.2425, accuracy: 0.9580
# Epoch: 9
# [Train]		 J_a: 151.5308, accuracy: 1.0000
# [Validation]	 J_a: 221.9546, accuracy: 0.9596
# Epoch: 10
# [Train]		 J_a: 151.4990, accuracy: 1.0000
# [Validation]	 J_a: 222.1659, accuracy: 0.9596
# Epoch: 11
# [Train]		 J_a: 151.4824, accuracy: 1.0000
# [Validation]	 J_a: 221.6778, accuracy: 0.9586
# Epoch: 12
# [Train]		 J_a: 151.4569, accuracy: 1.0000
# [Validation]	 J_a: 222.9474, accuracy: 0.9581
# Epoch: 13
# [Train]		 J_a: 151.4616, accuracy: 1.0000
# [Validation]	 J_a: 222.5075, accuracy: 0.9573
# Epoch: 14
# [Train]		 J_a: 151.4111, accuracy: 1.0000
# [Validation]	 J_a: 221.2705, accuracy: 0.9590
# Epoch: 15
# [Train]		 J_a: 151.3951, accuracy: 1.0000
# [Validation]	 J_a: 221.9549, accuracy: 0.9598
# Epoch: 16
# [Train]		 J_a: 151.4593, accuracy: 1.0000
# [Validation]	 J_a: 223.0666, accuracy: 0.9581
# Epoch: 17
# [Train]		 J_a: 151.4021, accuracy: 1.0000
# [Validation]	 J_a: 221.5134, accuracy: 0.9591
# Epoch: 18
# [Train]		 J_a: 151.3618, accuracy: 1.0000
# [Validation]	 J_a: 222.3805, accuracy: 0.9573
# Epoch: 19
# [Train]		 J_a: 151.3431, accuracy: 1.0000
# [Validation]	 J_a: 221.7494, accuracy: 0.9584
# Epoch: 20
# [Train]		 J_a: 151.3744, accuracy: 1.0000
# [Validation]	 J_a: 221.7939, accuracy: 0.9583
# Epoch: 21
# [Train]		 J_a: 151.3148, accuracy: 1.0000
# [Validation]	 J_a: 222.4693, accuracy: 0.9574
# Epoch: 22
# [Train]		 J_a: 151.2706, accuracy: 1.0000
# [Validation]	 J_a: 221.9944, accuracy: 0.9590
# Epoch: 23
# [Train]		 J_a: 151.2256, accuracy: 1.0000
# [Validation]	 J_a: 222.0962, accuracy: 0.9589
# Epoch: 24
# [Train]		 J_a: 151.2191, accuracy: 1.0000
# [Validation]	 J_a: 222.2823, accuracy: 0.9582
# Epoch: 25
# [Train]		 J_a: 151.1807, accuracy: 1.0000
# [Validation]	 J_a: 221.0258, accuracy: 0.9594
# Epoch: 26
# [Train]		 J_a: 151.1928, accuracy: 1.0000
# [Validation]	 J_a: 222.3187, accuracy: 0.9587
# Epoch: 27
# [Train]		 J_a: 151.1834, accuracy: 1.0000
# [Validation]	 J_a: 222.5757, accuracy: 0.9604
# Epoch: 28
# [Train]		 J_a: 151.2313, accuracy: 1.0000
# [Validation]	 J_a: 222.1961, accuracy: 0.9595
# Epoch: 29
# [Train]		 J_a: 151.2145, accuracy: 1.0000
# [Validation]	 J_a: 221.8252, accuracy: 0.9588
# Epoch: 30
# [Train]		 J_a: 151.1893, accuracy: 1.0000
# [Validation]	 J_a: 221.5071, accuracy: 0.9597
# Epoch: 31
# [Train]		 J_a: 151.1248, accuracy: 1.0000
# [Validation]	 J_a: 220.9981, accuracy: 0.9606
# Epoch: 32
# [Train]		 J_a: 151.1473, accuracy: 1.0000
# [Validation]	 J_a: 223.7209, accuracy: 0.9572
# Epoch: 33
# [Train]		 J_a: 151.1492, accuracy: 1.0000
# [Validation]	 J_a: 222.3553, accuracy: 0.9600
# Epoch: 34
# [Train]		 J_a: 151.1000, accuracy: 1.0000
# [Validation]	 J_a: 222.9578, accuracy: 0.9595
# Epoch: 35
# [Train]		 J_a: 151.1012, accuracy: 1.0000
# [Validation]	 J_a: 222.5002, accuracy: 0.9592
# Epoch: 36
# [Train]		 J_a: 151.1419, accuracy: 1.0000
# [Validation]	 J_a: 221.8103, accuracy: 0.9590
# Epoch: 37
# [Train]		 J_a: 151.0536, accuracy: 1.0000
# [Validation]	 J_a: 223.1094, accuracy: 0.9569
# Epoch: 38
# [Train]		 J_a: 151.0461, accuracy: 1.0000
# [Validation]	 J_a: 224.5884, accuracy: 0.9575
# Epoch: 39
# [Train]		 J_a: 151.0511, accuracy: 1.0000
# [Validation]	 J_a: 221.6960, accuracy: 0.9595
# Epoch: 40
# [Train]		 J_a: 151.0134, accuracy: 1.0000
# [Validation]	 J_a: 223.0628, accuracy: 0.9575
# Epoch: 41
# [Train]		 J_a: 150.9779, accuracy: 1.0000
# [Validation]	 J_a: 222.1583, accuracy: 0.9595
# Epoch: 42
# [Train]		 J_a: 150.9657, accuracy: 1.0000
# [Validation]	 J_a: 221.1855, accuracy: 0.9607
# Epoch: 43
# [Train]		 J_a: 150.9391, accuracy: 1.0000
# [Validation]	 J_a: 220.9484, accuracy: 0.9611
# Epoch: 44
# [Train]		 J_a: 150.9307, accuracy: 1.0000
# [Validation]	 J_a: 221.0001, accuracy: 0.9613
# Epoch: 45
# [Train]		 J_a: 150.9008, accuracy: 1.0000
# [Validation]	 J_a: 221.6076, accuracy: 0.9602
# Epoch: 46
# [Train]		 J_a: 150.8952, accuracy: 1.0000
# [Validation]	 J_a: 222.0567, accuracy: 0.9592
# Epoch: 47
# [Train]		 J_a: 150.8636, accuracy: 1.0000
# [Validation]	 J_a: 222.3407, accuracy: 0.9608
# Epoch: 48
# [Train]		 J_a: 150.8531, accuracy: 1.0000
# [Validation]	 J_a: 221.2627, accuracy: 0.9607
# Epoch: 49
# [Train]		 J_a: 150.8315, accuracy: 1.0000
# [Validation]	 J_a: 221.3932, accuracy: 0.9602
# Epoch: 50
# [Train]		 J_a: 150.8393, accuracy: 1.0000
# [Validation]	 J_a: 221.1075, accuracy: 0.9598
# Epoch: 51
# [Train]		 J_a: 150.8117, accuracy: 1.0000
# [Validation]	 J_a: 223.0993, accuracy: 0.9571
# Epoch: 52
# [Train]		 J_a: 150.7990, accuracy: 1.0000
# [Validation]	 J_a: 222.5843, accuracy: 0.9599
# Epoch: 53
# [Train]		 J_a: 150.8420, accuracy: 1.0000
# [Validation]	 J_a: 221.1170, accuracy: 0.9608
# Epoch: 54
# [Train]		 J_a: 150.7790, accuracy: 1.0000
# [Validation]	 J_a: 222.8897, accuracy: 0.9577
# Epoch: 55
# [Train]		 J_a: 150.7702, accuracy: 1.0000
# [Validation]	 J_a: 221.6703, accuracy: 0.9594
# Epoch: 56
# [Train]		 J_a: 150.8471, accuracy: 1.0000
# [Validation]	 J_a: 220.9408, accuracy: 0.9598
# Epoch: 57
# [Train]		 J_a: 150.7509, accuracy: 1.0000
# [Validation]	 J_a: 221.1592, accuracy: 0.9596
# Epoch: 58
# [Train]		 J_a: 150.7474, accuracy: 1.0000
# [Validation]	 J_a: 220.9085, accuracy: 0.9585
# Epoch: 59
# [Train]		 J_a: 150.7062, accuracy: 1.0000
# [Validation]	 J_a: 220.0562, accuracy: 0.9601
# Epoch: 60
# [Train]		 J_a: 150.7174, accuracy: 1.0000
# [Validation]	 J_a: 220.2870, accuracy: 0.9619
# Epoch: 61
# [Train]		 J_a: 150.7060, accuracy: 1.0000
# [Validation]	 J_a: 220.6027, accuracy: 0.9599
# Epoch: 62
# [Train]		 J_a: 150.6816, accuracy: 1.0000
# [Validation]	 J_a: 220.9157, accuracy: 0.9605
# Epoch: 63
# [Train]		 J_a: 150.6750, accuracy: 1.0000
# [Validation]	 J_a: 220.6040, accuracy: 0.9605
# Epoch: 64
# [Train]		 J_a: 150.6592, accuracy: 1.0000
# [Validation]	 J_a: 221.0955, accuracy: 0.9606
# Epoch: 65
# [Train]		 J_a: 150.5983, accuracy: 1.0000
# [Validation]	 J_a: 222.5079, accuracy: 0.9582
# Epoch: 66
# [Train]		 J_a: 150.5948, accuracy: 1.0000
# [Validation]	 J_a: 221.6077, accuracy: 0.9600
# Epoch: 67
# [Train]		 J_a: 150.5909, accuracy: 1.0000
# [Validation]	 J_a: 222.4897, accuracy: 0.9592
# Epoch: 68
# [Train]		 J_a: 150.5946, accuracy: 1.0000
# [Validation]	 J_a: 221.4947, accuracy: 0.9595
# Epoch: 69
# [Train]		 J_a: 150.5859, accuracy: 1.0000
# [Validation]	 J_a: 223.8329, accuracy: 0.9571
# Epoch: 70
# [Train]		 J_a: 150.5466, accuracy: 1.0000
# [Validation]	 J_a: 221.5964, accuracy: 0.9597
# Epoch: 71
# [Train]		 J_a: 150.5284, accuracy: 1.0000
# [Validation]	 J_a: 221.0402, accuracy: 0.9614
# Epoch: 72
# [Train]		 J_a: 150.5206, accuracy: 1.0000
# [Validation]	 J_a: 222.3804, accuracy: 0.9601
# Epoch: 73
# [Train]		 J_a: 150.5035, accuracy: 1.0000
# [Validation]	 J_a: 221.0724, accuracy: 0.9607
# Epoch: 74
# [Train]		 J_a: 150.4982, accuracy: 1.0000
# [Validation]	 J_a: 221.8701, accuracy: 0.9596
# Epoch: 75
# [Train]		 J_a: 150.4680, accuracy: 1.0000
# [Validation]	 J_a: 222.8725, accuracy: 0.9586
# Epoch: 76
# [Train]		 J_a: 150.4679, accuracy: 1.0000
# [Validation]	 J_a: 221.4803, accuracy: 0.9599
# Epoch: 77
# [Train]		 J_a: 150.4881, accuracy: 1.0000
# [Validation]	 J_a: 221.3356, accuracy: 0.9589
# Epoch: 78
# [Train]		 J_a: 150.4599, accuracy: 1.0000
# [Validation]	 J_a: 222.2861, accuracy: 0.9596
# Epoch: 79
# [Train]		 J_a: 150.4529, accuracy: 1.0000
# [Validation]	 J_a: 223.7549, accuracy: 0.9569
# Epoch: 80
# [Train]		 J_a: 150.4640, accuracy: 1.0000
# [Validation]	 J_a: 221.4495, accuracy: 0.9592
# Epoch: 81
# [Train]		 J_a: 150.4346, accuracy: 1.0000
# [Validation]	 J_a: 223.3962, accuracy: 0.9576
# Epoch: 82
# [Train]		 J_a: 150.4461, accuracy: 1.0000
# [Validation]	 J_a: 222.9280, accuracy: 0.9592
# Epoch: 83
# [Train]		 J_a: 150.4965, accuracy: 1.0000
# [Validation]	 J_a: 223.1122, accuracy: 0.9584
# Epoch: 84
# [Train]		 J_a: 150.4447, accuracy: 1.0000
# [Validation]	 J_a: 223.5260, accuracy: 0.9580
# Epoch: 85
# [Train]		 J_a: 150.4106, accuracy: 1.0000
# [Validation]	 J_a: 220.4818, accuracy: 0.9614
# Epoch: 86
# [Train]		 J_a: 150.3769, accuracy: 1.0000
# [Validation]	 J_a: 221.5065, accuracy: 0.9603
# Epoch: 87
# [Train]		 J_a: 150.3329, accuracy: 1.0000
# [Validation]	 J_a: 221.7570, accuracy: 0.9602
# Epoch: 88
# [Train]		 J_a: 150.3370, accuracy: 1.0000
# [Validation]	 J_a: 221.2264, accuracy: 0.9610
# Epoch: 89
# [Train]		 J_a: 150.3112, accuracy: 1.0000
# [Validation]	 J_a: 221.8623, accuracy: 0.9611
# Epoch: 90
# [Train]		 J_a: 150.3384, accuracy: 1.0000
# [Validation]	 J_a: 225.8432, accuracy: 0.9549
# Epoch: 91
# [Train]		 J_a: 150.3151, accuracy: 1.0000
# [Validation]	 J_a: 221.7168, accuracy: 0.9578
# Epoch: 92
# [Train]		 J_a: 150.2829, accuracy: 1.0000
# [Validation]	 J_a: 221.0278, accuracy: 0.9621
# Epoch: 93
# [Train]		 J_a: 150.2577, accuracy: 1.0000
# [Validation]	 J_a: 222.8739, accuracy: 0.9581
# Epoch: 94
# [Train]		 J_a: 150.2536, accuracy: 1.0000
# [Validation]	 J_a: 221.8911, accuracy: 0.9587
# Epoch: 95
# [Train]		 J_a: 150.2810, accuracy: 1.0000
# [Validation]	 J_a: 223.0223, accuracy: 0.9603
# Epoch: 96
# [Train]		 J_a: 150.2554, accuracy: 1.0000
# [Validation]	 J_a: 222.5601, accuracy: 0.9587
# Epoch: 97
# [Train]		 J_a: 150.2692, accuracy: 1.0000
# [Validation]	 J_a: 221.6206, accuracy: 0.9604
# Epoch: 98
# [Train]		 J_a: 150.2330, accuracy: 1.0000
# [Validation]	 J_a: 220.1631, accuracy: 0.9622
# Epoch: 99
# [Train]		 J_a: 150.2534, accuracy: 1.0000
# [Validation]	 J_a: 223.5712, accuracy: 0.9596
# Epoch: 100
# [Train]		 J_a: 150.2361, accuracy: 1.0000
# [Validation]	 J_a: 222.4589, accuracy: 0.9579
# Epoch: 101
# [Train]		 J_a: 150.2164, accuracy: 1.0000
# [Validation]	 J_a: 222.3446, accuracy: 0.9595
# Epoch: 102
# [Train]		 J_a: 150.1765, accuracy: 1.0000
# [Validation]	 J_a: 221.1921, accuracy: 0.9614
# Epoch: 103
# [Train]		 J_a: 150.2113, accuracy: 1.0000
# [Validation]	 J_a: 220.5561, accuracy: 0.9616
# Epoch: 104
# [Train]		 J_a: 150.2348, accuracy: 1.0000
# [Validation]	 J_a: 220.6483, accuracy: 0.9615
# Epoch: 105
# [Train]		 J_a: 150.1811, accuracy: 1.0000
# [Validation]	 J_a: 222.1650, accuracy: 0.9601
# Epoch: 106
# [Train]		 J_a: 150.1758, accuracy: 1.0000
# [Validation]	 J_a: 221.2092, accuracy: 0.9601
# Epoch: 107
# [Train]		 J_a: 150.1461, accuracy: 1.0000
# [Validation]	 J_a: 222.4725, accuracy: 0.9604
# Epoch: 108
# [Train]		 J_a: 150.1492, accuracy: 1.0000
# [Validation]	 J_a: 221.3657, accuracy: 0.9597
# Epoch: 109
# [Train]		 J_a: 150.1045, accuracy: 1.0000
# [Validation]	 J_a: 222.2102, accuracy: 0.9596
# Epoch: 110
# [Train]		 J_a: 150.0942, accuracy: 1.0000
# [Validation]	 J_a: 221.0950, accuracy: 0.9604
# Epoch: 111
# [Train]		 J_a: 150.0451, accuracy: 1.0000
# [Validation]	 J_a: 221.6442, accuracy: 0.9604
# Epoch: 112
# [Train]		 J_a: 150.0472, accuracy: 1.0000
# [Validation]	 J_a: 221.0536, accuracy: 0.9603
# Epoch: 113
# [Train]		 J_a: 150.0900, accuracy: 1.0000
# [Validation]	 J_a: 222.1825, accuracy: 0.9601
# Epoch: 114
# [Train]		 J_a: 150.0716, accuracy: 1.0000
# [Validation]	 J_a: 221.1310, accuracy: 0.9600
# Epoch: 115
# [Train]		 J_a: 150.1057, accuracy: 1.0000
# [Validation]	 J_a: 223.0548, accuracy: 0.9600
# Epoch: 116
# [Train]		 J_a: 150.0708, accuracy: 1.0000
# [Validation]	 J_a: 220.0052, accuracy: 0.9601
# Epoch: 117
# [Train]		 J_a: 150.0563, accuracy: 1.0000
# [Validation]	 J_a: 222.2462, accuracy: 0.9596
# Epoch: 118
# [Train]		 J_a: 150.0269, accuracy: 1.0000
# [Validation]	 J_a: 222.1629, accuracy: 0.9609
# Epoch: 119
# [Train]		 J_a: 149.9856, accuracy: 1.0000
# [Validation]	 J_a: 221.0205, accuracy: 0.9607
# Epoch: 120
# [Train]		 J_a: 149.9972, accuracy: 1.0000
# [Validation]	 J_a: 221.1355, accuracy: 0.9595
# Epoch: 121
# [Train]		 J_a: 149.9952, accuracy: 1.0000
# [Validation]	 J_a: 220.8588, accuracy: 0.9605
# Epoch: 122
# [Train]		 J_a: 149.9686, accuracy: 1.0000
# [Validation]	 J_a: 220.7060, accuracy: 0.9608
# Epoch: 123
# [Train]		 J_a: 149.9539, accuracy: 1.0000
# [Validation]	 J_a: 221.9663, accuracy: 0.9597
# Epoch: 124
# [Train]		 J_a: 149.9689, accuracy: 1.0000
# [Validation]	 J_a: 221.1234, accuracy: 0.9587
# Epoch: 125
# [Train]		 J_a: 150.0576, accuracy: 1.0000
# [Validation]	 J_a: 221.5810, accuracy: 0.9603
# Epoch: 126
# [Train]		 J_a: 149.9708, accuracy: 1.0000
# [Validation]	 J_a: 221.4338, accuracy: 0.9592
# Epoch: 127
# [Train]		 J_a: 150.0453, accuracy: 1.0000
# [Validation]	 J_a: 220.4801, accuracy: 0.9611
# Epoch: 128
# [Train]		 J_a: 149.9788, accuracy: 1.0000
# [Validation]	 J_a: 221.2667, accuracy: 0.9599
# Epoch: 129
# [Train]		 J_a: 149.9380, accuracy: 1.0000
# [Validation]	 J_a: 219.9254, accuracy: 0.9607
# Epoch: 130
# [Train]		 J_a: 149.8900, accuracy: 1.0000
# [Validation]	 J_a: 220.3224, accuracy: 0.9612
# Epoch: 131
# [Train]		 J_a: 149.9166, accuracy: 1.0000
# [Validation]	 J_a: 220.6071, accuracy: 0.9605
# Epoch: 132
# [Train]		 J_a: 149.9131, accuracy: 1.0000
# [Validation]	 J_a: 222.6774, accuracy: 0.9598
# Epoch: 133
# [Train]		 J_a: 149.9302, accuracy: 1.0000
# [Validation]	 J_a: 220.9037, accuracy: 0.9605
# Epoch: 134
# [Train]		 J_a: 149.8723, accuracy: 1.0000
# [Validation]	 J_a: 221.6769, accuracy: 0.9582
# Epoch: 135
# [Train]		 J_a: 149.8561, accuracy: 1.0000
# [Validation]	 J_a: 220.5788, accuracy: 0.9597
# Epoch: 136
# [Train]		 J_a: 149.8679, accuracy: 1.0000
# [Validation]	 J_a: 221.4438, accuracy: 0.9591
# Epoch: 137
# [Train]		 J_a: 149.8324, accuracy: 1.0000
# [Validation]	 J_a: 221.9659, accuracy: 0.9583
# Epoch: 138
# [Train]		 J_a: 149.8343, accuracy: 1.0000
# [Validation]	 J_a: 220.3933, accuracy: 0.9610
# Epoch: 139
# [Train]		 J_a: 149.8481, accuracy: 1.0000
# [Validation]	 J_a: 220.8175, accuracy: 0.9593
# Epoch: 140
# [Train]		 J_a: 149.8008, accuracy: 1.0000
# [Validation]	 J_a: 220.7186, accuracy: 0.9605
# Epoch: 141
# [Train]		 J_a: 149.7866, accuracy: 1.0000
# [Validation]	 J_a: 222.1157, accuracy: 0.9591
# Epoch: 142
# [Train]		 J_a: 149.7858, accuracy: 1.0000
# [Validation]	 J_a: 221.0452, accuracy: 0.9615
# Epoch: 143
# [Train]		 J_a: 149.7643, accuracy: 1.0000
# [Validation]	 J_a: 220.5882, accuracy: 0.9605
# Epoch: 144
# [Train]		 J_a: 149.7744, accuracy: 1.0000
# [Validation]	 J_a: 221.6955, accuracy: 0.9601

# %%
print(accuracy / m)
print(epoch)

# %% [markdown]
# ## Conditional generation
#
# When the model is done training you can generate samples conditionally given some normal distributed noise $z$ and a label $y$.
#
# *The model below has only trained for 10 iterations, so the perfomance is not representative*.

# %%
from utils import onehot
model.eval()

z_dim = 100
z = torch.randn(100, z_dim).repeat(1, 1).cuda()

# Generate a batch of 5s
ys = []
for y_idx in range(10):
    for step in range(10):
        interval = step / 10
        one_hot = [0] * 10
        one_hot[y_idx] = (1 - interval)
        one_hot[(y_idx + 1) % 10] = interval
        ys += [one_hot]
y = torch.tensor(ys).view(10 * 10, -1).cuda()
print(y.shape)


# z = torch.randn(5, 1, z_dim).repeat(1, 16, 1).reshape(5 * 16, z_dim).cuda()
# y = np.zeros((5, 16, 10))

# for y_idx in range(16):
#     y[:, y_idx, 4] = y_idx / 16
#     y[:, y_idx, 5] = 1 - (y_idx / 16)
# y = torch.tensor(y.reshape(5 * 16, 10)).cuda()

y = (y + 0.5).int().float()

y = np.zeros((100, y_dim))
for idx in range(10):
    y[10 * idx:10 * (idx+1), idx] = 1.
y = torch.tensor(y).float().cuda()
x_mu = model.sample(z, y)

print(x_mu.shape)
# Out:
# torch.Size([100, 10])
# torch.Size([100, 784])

# %%
f, axarr = plt.subplots(10, 10, figsize=(10, 10))

samples = x_mu.cpu().data.view(-1, 28, 28).numpy()
# samples = x_mu.data.view(-1, 3, 32, 32).cpu().numpy().transpose(0, 2, 3, 1)


# mnist_means = np.tile(mnist_mean.reshape((1, -1)), (len(samples), 1))
# mnist_means[:, mnist_std > 0.1] = samples
# samples = mnist_means.reshape(-1, 28, 28)


for i, ax in enumerate(axarr.flat):
    ax.imshow(samples[i], cmap="gray")
    ax.axis("off")
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
# torch.save(model.state_dict(), "./adgm_mnist_new.ckpt")
