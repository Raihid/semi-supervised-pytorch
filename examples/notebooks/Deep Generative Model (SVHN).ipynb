# %% [markdown]
# # Deep Generative Model
#
# In this notebook we show how you can use the deep "generative model for semi-supervised learning" as presented in [[Kingma 2014]](https://arxiv.org/abs/1406.5298). The paper posits three different models, though we are just interested in two of these: the M2 model and the M1+M2 model.
#
# The M1 model is just a variational autoencoder, so we refer to the previous notebook for more information on this. The M2 model however is an extension to the VAE to include label information for a semi-supervised objective. The structure is shown below (left: inference model, right: generative model).
#
# <img src="../images/dgm.png" width="400px"/>
#
# The point of the generative model is to seperate the partially observed label information $y$ from the latent variable $z$ in order to learn a representation that seperates these two variables. We can use this model for semi-supervised learning as the inference model must also infer the label from the data $x$ along with the latent variable $z$.

# %%
# Imports
import torch
cuda = torch.cuda.is_available()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append("../../semi-supervised")
from models import DeepGenerativeModel, StackedDeepGenerativeModel

# %% [markdown]
# Notice how theres now a classifier associated with model. This classifier will just be a simple model that takes the size of the first layer encoder network. We also have a larger input space on both the encoder and decoder to make room for label information, in this case 10 labels.

# %% [markdown]
# ## Stacked Deep Generative Model
#
# The M1+M2 model also described in the same paper is an M1 model (VAE) with an M2 model stacked on top of it. That means that we train the a VAE end-to-end on the data given dataset, then we use the learned encoder as a feature extractor and feed the data transformed by the M1 encoder into the M2 model.
#
# We approach is somewhat similar to restricted boltzmann machines (RBMs) in the sense that we perform a layerwise training of the whole model by first training a level-1 feature extractor and stacking another model on top of this. The stacked model is therefore also more modular, but cannot be trained end-to-end, which is a downside.

# %%
from models import VariationalAutoencoder, StackedDeepGenerativeModel

features = VariationalAutoencoder([32 * 32 * 3, 300, [600, 600]], activation_fn=torch.nn.Softplus, batch_norm=False).cuda()
stacked = StackedDeepGenerativeModel(
    [32 * 32 * 3, 10, 100, [500]], features,
    activation_fn=torch.nn.Softplus, batch_norm=False
)
features.load_state_dict(torch.load("./vae_svhn_new.ckpt"))
model = stacked.dgm
# Out:
# ../../semi-supervised/models/vae.py:237: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   init.xavier_normal(m.weight.data)
# 300
# Linear layers in classifier [Softplus(beta=1, threshold=20)]
# ../../semi-supervised/models/dgm.py:110: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   init.xavier_normal(m.weight.data)

# %% [markdown]
# Typically, you would want to load a pretrained feature extractor VAE instead.

# %%
from datautils import get_celeba, get_mnist, get_svhn

# labelled, unlabelled, validation, labels_names = get_celeba(location="./", batch_size=256)
labelled, unlabelled, validation, _ = get_svhn(location="./", batch_size=1000, labels_per_class=100, extra=True)

alpha = 0.1 * len(unlabelled)

def binary_cross_entropy(r, x):
    return -torch.sum(x * torch.log(r + 1e-8) + (1 - x) * torch.log(1 - r + 1e-8), dim=-1)
    # return -F.binary_cross_entropy(r, x, reduction="sum")

def mse(r, x):
    x = x.view(x.shape[0], -1)
    r = r.view(r.shape[0], -1)
    return torch.sum(torch.pow(x - r, 2), dim=-1)

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999), weight_decay=0.5 / len(unlabelled))
# Out:
# Using downloaded and verified file: ./train_32x32.mat
# Using downloaded and verified file: ./extra_32x32.mat
# Len of svhn train 604388
# Using downloaded and verified file: ./test_32x32.mat

# %%
from itertools import cycle
from inference import SVI, ImportanceWeightedSampler
import torch.nn.functional as F

# You can use importance weighted samples [Burda, 2015] to get a better estimate
# on the log-likelihood.
sampler = ImportanceWeightedSampler(mc=1, iw=1)

if cuda: model = model.cuda()
elbo = SVI(model, likelihood=mse)

# %%
from torch.autograd import Variable
from tqdm import tnrange


torch.multiprocessing.set_sharing_strategy('file_system')

for epoch in tnrange(200):
    model.train()
    total_loss, accuracy = (0, 0)
    idx = 0
    for (x, y), (u, _) in zip(cycle(labelled), unlabelled):
        # Wrap in variables
        x, y, u = Variable(x), Variable(y), Variable(u)
        

        if cuda:
            # They need to be on the same device and be synchronized.
            x, y = x.cuda(device=0), y.cuda(device=0)
            u = u.cuda(device=0)
        z_x, _, _ = features.encoder(x)
        z_u, _, _ = features.encoder(u)

        # print(x.shape)
        L = -elbo(z_x, y)
        U = -elbo(z_u)

        # Add auxiliary classification loss q(y|x)
        logits = model.classify(z_x)
        
        # Regular cross entropy
        classication_loss = torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

        # print("idx", idx, "L", L.item(), "U", U.item(), "class", classication_loss.item())
        J_alpha = L - alpha * classication_loss + U
        
        if torch.isnan(J_alpha):
            print(z_u)
            continue 
        J_alpha.backward()
        optimizer.step()
        optimizer.zero_grad()

        total_loss += J_alpha.item()
        accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())
        idx += 1
        
    if epoch % 5 == 0:
        model.eval()
        m = len(unlabelled)
        print("Epoch: {}".format(epoch))
        print("[Train]\t\t J_a: {:.4f}, accuracy: {:.4f}".format(total_loss / m, accuracy / m))

        total_loss, accuracy = (0, 0)
        for x, y in validation:
            x, y = Variable(x), Variable(y)

            if cuda:
                x, y = x.cuda(device=0), y.cuda(device=0)

            # _, z_x _ = features.encoder(x)
            z_x, _, _ = features.encoder(x)
            
            L = -elbo(z_x, y)
            U = -elbo(z_x)

            logits = model.classify(z_x)
            classication_loss = -torch.sum(y * torch.log(logits + 1e-8), dim=1).mean()

            J_alpha = L + alpha * classication_loss + U

            total_loss += J_alpha.item()

            _, pred_idx = torch.max(logits, 1)
            _, lab_idx = torch.max(y, 1)
            accuracy += torch.mean((torch.max(logits, 1)[1].data == torch.max(y, 1)[1].data).float())

        m = len(validation)
        print("[Validation]\t J_a: {:.4f}, accuracy: {:.4f}".format(total_loss / m, accuracy / m))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Epoch: 0
# [Train]		 J_a: 741.0809, accuracy: 0.2013
# [Validation]	 J_a: 716.1478, accuracy: 0.2084
# Epoch: 5
# [Train]		 J_a: 654.4759, accuracy: 0.5534
# [Validation]	 J_a: 684.6433, accuracy: 0.4061
# Epoch: 10
# [Train]		 J_a: 649.2049, accuracy: 0.5805
# [Validation]	 J_a: 689.0661, accuracy: 0.4027
# Epoch: 15
# [Train]		 J_a: 647.4633, accuracy: 0.5896
# [Validation]	 J_a: 689.2063, accuracy: 0.4050
# Epoch: 20
# [Train]		 J_a: 645.5487, accuracy: 0.5998
# [Validation]	 J_a: 690.8784, accuracy: 0.3973
# Epoch: 25
# [Train]		 J_a: 643.3465, accuracy: 0.6132
# [Validation]	 J_a: 691.5999, accuracy: 0.4034
# Epoch: 30
# [Train]		 J_a: 640.6510, accuracy: 0.6278
# [Validation]	 J_a: 691.5331, accuracy: 0.4006
# Epoch: 35
# [Train]		 J_a: 637.5341, accuracy: 0.6447
# [Validation]	 J_a: 692.3173, accuracy: 0.4017
# Epoch: 40
# [Train]		 J_a: 634.4211, accuracy: 0.6625
# [Validation]	 J_a: 694.3540, accuracy: 0.3979
# Epoch: 45
# [Train]		 J_a: 631.6131, accuracy: 0.6772
# [Validation]	 J_a: 697.3712, accuracy: 0.3840
# Epoch: 50
# [Train]		 J_a: 628.8087, accuracy: 0.6910
# [Validation]	 J_a: 699.1518, accuracy: 0.3834
# Epoch: 55
# [Train]		 J_a: 626.3932, accuracy: 0.7042
# [Validation]	 J_a: 700.4148, accuracy: 0.3803
# Epoch: 60
# [Train]		 J_a: 624.5162, accuracy: 0.7140
# [Validation]	 J_a: 703.8364, accuracy: 0.3787
# Epoch: 65
# [Train]		 J_a: 622.7840, accuracy: 0.7229
# [Validation]	 J_a: 707.9513, accuracy: 0.3785
# Epoch: 70
# [Train]		 J_a: 621.3288, accuracy: 0.7302
# [Validation]	 J_a: 710.8734, accuracy: 0.3710
# Epoch: 75
# [Train]		 J_a: 620.1633, accuracy: 0.7369
# [Validation]	 J_a: 712.2599, accuracy: 0.3682
# Epoch: 80
# [Train]		 J_a: 618.9506, accuracy: 0.7422
# [Validation]	 J_a: 713.7552, accuracy: 0.3711
# Epoch: 85
# [Train]		 J_a: 617.9967, accuracy: 0.7472
# [Validation]	 J_a: 715.1959, accuracy: 0.3651
# Epoch: 90
# [Train]		 J_a: 616.9579, accuracy: 0.7531
# [Validation]	 J_a: 719.1784, accuracy: 0.3629
# Epoch: 95
# [Train]		 J_a: 616.1586, accuracy: 0.7565
# [Validation]	 J_a: 720.6446, accuracy: 0.3633
# Epoch: 100
# [Train]		 J_a: 615.4722, accuracy: 0.7603
# [Validation]	 J_a: 721.5854, accuracy: 0.3574
# Epoch: 105
# [Train]		 J_a: 614.7038, accuracy: 0.7636
# [Validation]	 J_a: 723.7158, accuracy: 0.3661
# Epoch: 110
# [Train]		 J_a: 614.1490, accuracy: 0.7656
# [Validation]	 J_a: 725.1635, accuracy: 0.3594
# Epoch: 115
# [Train]		 J_a: 613.5030, accuracy: 0.7704
# [Validation]	 J_a: 726.7900, accuracy: 0.3610
# Epoch: 120
# [Train]		 J_a: 613.0255, accuracy: 0.7720
# [Validation]	 J_a: 728.8337, accuracy: 0.3550
# Epoch: 125
# [Train]		 J_a: 612.4058, accuracy: 0.7751
# [Validation]	 J_a: 731.9444, accuracy: 0.3521
# Epoch: 130
# [Train]		 J_a: 612.0099, accuracy: 0.7773
# [Validation]	 J_a: 731.3615, accuracy: 0.3593
# Epoch: 135
# [Train]		 J_a: 611.6171, accuracy: 0.7789
# [Validation]	 J_a: 733.7954, accuracy: 0.3565
# Epoch: 140
# [Train]		 J_a: 611.0501, accuracy: 0.7817
# [Validation]	 J_a: 734.9395, accuracy: 0.3519
# Epoch: 145
# [Train]		 J_a: 610.7729, accuracy: 0.7823
# [Validation]	 J_a: 734.7470, accuracy: 0.3518
# Epoch: 150
# [Train]		 J_a: 610.3463, accuracy: 0.7847
# [Validation]	 J_a: 738.4661, accuracy: 0.3468
# Epoch: 155
# [Train]		 J_a: 610.0161, accuracy: 0.7861
# [Validation]	 J_a: 738.9055, accuracy: 0.3465
# Epoch: 160
# [Train]		 J_a: 609.7621, accuracy: 0.7879
# [Validation]	 J_a: 740.5357, accuracy: 0.3471
# Epoch: 165
# [Train]		 J_a: 609.1714, accuracy: 0.7897
# [Validation]	 J_a: 738.2039, accuracy: 0.3516
# Epoch: 170
# [Train]		 J_a: 609.0037, accuracy: 0.7912
# [Validation]	 J_a: 739.6359, accuracy: 0.3459
# Epoch: 175
# [Train]		 J_a: 608.7985, accuracy: 0.7923
# [Validation]	 J_a: 740.8226, accuracy: 0.3476
# Epoch: 180
# [Train]		 J_a: 608.4512, accuracy: 0.7937
# [Validation]	 J_a: 743.5941, accuracy: 0.3486
# Epoch: 185
# [Train]		 J_a: 608.0578, accuracy: 0.7951
# [Validation]	 J_a: 743.1270, accuracy: 0.3461
# Epoch: 190
# [Train]		 J_a: 607.8511, accuracy: 0.7961
# [Validation]	 J_a: 745.1367, accuracy: 0.3442
# Epoch: 195
# [Train]		 J_a: 607.5667, accuracy: 0.7977
# [Validation]	 J_a: 744.4217, accuracy: 0.3492

# %%
model
# Out:
# DeepGenerativeModel(
#   (encoder): Encoder(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=300, out_features=500, bias=True)
#       (1): Linear(in_features=10, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): Softplus(beta=1, threshold=20)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=500, out_features=100, bias=True)
#       (log_var): Linear(in_features=500, out_features=100, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=100, out_features=500, bias=True)
#       (1): Linear(in_features=10, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): Softplus(beta=1, threshold=20)
#     )
#     (reconstruction): Linear(in_features=500, out_features=300, bias=True)
#   )
#   (classifier): Classifier(
#     (first_dense): ModuleList(
#       (0): Linear(in_features=300, out_features=500, bias=True)
#     )
#     (hidden): ModuleList(
#       (0): Softplus(beta=1, threshold=20)
#     )
#     (logits): Linear(in_features=500, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Conditional generation
#
# When the model is done training you can generate samples conditionally given some normal distributed noise $z$ and a label $y$.
#
# *The model below has only trained for 10 iterations, so the perfomance is not representative*.

# %%
from utils import onehot
model.eval()

model.eval()

z_dim = 100

x, y = next(iter(validation))

_, z, _ = features.encoder(x[2].unsqueeze(0).cuda())
_, z, _ = model.encoder(z)
z = z.repeat(100, 1)
print(z.shape)

# Generate a batch of 5s
ys = []
for y_idx in range(10):
    for step in range(10):
        interval = step / 9
        one_hot = [0] * 10
        one_hot[y_idx] = (1 - interval)
        one_hot[(y_idx + 1) % 10] = interval
        ys += [one_hot]
y = torch.tensor(ys).view(10 * 10, -1).cuda()


# z = torch.randn(5, 1, z_dim).repeat(1, 16, 1).reshape(5 * 16, z_dim).cuda()
# y = np.zeros((5, 16, 10))

# for y_idx in range(16):
#     y[:, y_idx, 4] = y_idx / 16
#     y[:, y_idx, 5] = 1 - (y_idx / 16)
# y = torch.tensor(y.reshape(5 * 16, 10)).cuda()
x_mu = model.decoder([z, y])
x_mu = features.decoder(x_mu)


z_dim = 100
z = torch.randn(100, z_dim).repeat(1, 1).cuda()

print(x_mu)
x_mu = stacked.sample(z, (y + 0.5).int())
# Out:
# torch.Size([100, 100])
# tensor([[0.4313, 0.4313, 0.4314,  ..., 0.4647, 0.4644, 0.4631],
#         [0.4227, 0.4227, 0.4227,  ..., 0.4550, 0.4550, 0.4538],
#         [0.4170, 0.4170, 0.4169,  ..., 0.4480, 0.4482, 0.4472],
#         ...,
#         [0.4195, 0.4195, 0.4196,  ..., 0.4498, 0.4500, 0.4490],
#         [0.4252, 0.4252, 0.4253,  ..., 0.4571, 0.4570, 0.4559],
#         [0.4313, 0.4313, 0.4314,  ..., 0.4647, 0.4644, 0.4631]],
#        device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
f, axarr = plt.subplots(10, 10, figsize=(10, 10))

samples = x_mu.data.view(-1, 3, 32, 32).cpu().numpy().transpose(0, 2, 3, 1)

for i, ax in enumerate(axarr.flat):
    ax.imshow(samples[i])
    ax.set_xticks([])
    ax.set_yticks([])

    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# torch.save(model.state_dict(), "m1m2_svhn_new.ckpt")
